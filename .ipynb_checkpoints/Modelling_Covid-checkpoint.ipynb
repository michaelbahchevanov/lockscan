# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np

import datetime
from datetime import date

import matplotlib.pyplot as plt
import seaborn as sns

import math
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error

from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from fbprophet import Prophet

np.random.seed(21)

# %%
df = pd.read_csv('./data/nl-data.csv')

# %%
df.head()
# Out:
#          date   total_cases  people_vaccinated  people_fully_vaccinated  \
# 0  2020-03-08    193.666667                0.0                      0.0
# 1  2020-03-15    659.285714                0.0                      0.0
# 2  2020-03-22   2644.571429                0.0                      0.0
# 3  2020-03-29   7663.714286                0.0                      0.0
# 4  2020-04-05  14781.285714                0.0                      0.0
#
#    hosp_patients  total_deaths   total_tests  stringency_index  \
# 0      92.666667      1.666667      0.000000         11.110000
# 1     298.142857      8.428571   2440.000000         37.034286
# 2    1233.571429     89.428571  29273.142857         61.110000
# 3    2906.428571    463.142857  52558.000000         78.700000
# 4    2845.857143   1334.000000  79790.428571         78.700000
#
#    total_cases_diff  people_fully_vaccinated_diff  hosp_patients_diff  \
# 0          0.000000                           0.0            0.000000
# 1        465.619048                           0.0          205.476190
# 2       1519.666667                           0.0          935.428571
# 3       3033.857143                           0.0         1672.857143
# 4       2098.428571                           0.0          -60.571429
#
#    total_deaths_diff  total_tests_diff  stringency_index_diff  \
# 0           0.000000          0.000000               0.000000
# 1           6.761905       2440.000000              25.924286
# 2          74.238095      24393.142857              24.075714
# 3         292.714286      -3548.285714              17.590000
# 4         497.142857       3947.571429               0.000000
#
#    total_cases_trend  total_cases_seasonal  people_vaccinated_trend  \
# 0       -7699.116667           -369.083409                      0.0
# 1       -1858.880952           -652.622223                      0.0
# 2        4613.761905            172.996824                      0.0
# 3        9118.839286            848.708808                      0.0
# 4       15170.107143           -369.083409                      0.0
#
#    people_vaccinated_seasonal  people_fully_vaccinated_trend  \
# 0               -17793.667375                            0.0
# 1                -4812.723811                            0.0
# 2                12130.207141                            0.0
# 3                10476.184046                            0.0
# 4               -17793.667375                            0.0
#
#    people_fully_vaccinated_seasonal  hosp_patients_trend  \
# 0                      -4775.862070           876.235119
# 1                       2608.896523          1250.494048
# 2                       3475.584619          1476.851190
# 3                      -1308.619072          2125.053571
# 4                      -4775.862070          2564.892857
#
#    hosp_patients_seasonal  total_deaths_trend  total_deaths_seasonal  \
# 0              -29.187786        -1147.230952              37.982584
# 1              -44.212947         -471.907738              20.448755
# 2               -1.324852          307.208333             -25.079221
# 3               74.725585          768.410714             -33.352118
# 4              -29.187786         1463.339286              37.982584
#
#    total_tests_trend  total_tests_seasonal  stringency_index_trend  \
# 0      -29367.078571         -19421.186488               42.914964
# 1        -365.625000           9300.968274               50.634464
# 2       31041.589286          14548.774226               55.437321
# 3       55025.875000          -4428.556012               69.094286
# 4       84644.267857         -19421.186488               76.501250
#
#    stringency_index_seasonal  total_cases_seasonal_shift_b_2m  \
# 0                  -0.907891                      -369.083409
# 1                  -0.620532                      -652.622223
# 2                   0.479515                       172.996824
# 3                   1.048908                       848.708808
# 4                  -0.907891                      -369.083409
#
#    total_cases_seasonal_shift_b_1m  total_cases_seasonal_shift_1m  \
# 0                      -369.083409                            NaN
# 1                      -652.622223                            NaN
# 2                       172.996824                            NaN
# 3                       848.708808                            NaN
# 4                      -369.083409                    -369.083409
#
#    total_cases_seasonal_shift_2m  total_cases_seasonal_shift_3m  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    people_vaccinated_seasonal_shift_b_2m  \
# 0                          -17793.667375
# 1                           -4812.723811
# 2                           12130.207141
# 3                           10476.184046
# 4                          -17793.667375
#
#    people_vaccinated_seasonal_shift_b_1m  people_vaccinated_seasonal_shift_1m  \
# 0                          -17793.667375                                  NaN
# 1                           -4812.723811                                  NaN
# 2                           12130.207141                                  NaN
# 3                           10476.184046                                  NaN
# 4                          -17793.667375                        -17793.667375
#
#    people_vaccinated_seasonal_shift_2m  people_vaccinated_seasonal_shift_3m  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    people_fully_vaccinated_seasonal_shift_b_2m  \
# 0                                 -4775.862070
# 1                                  2608.896523
# 2                                  3475.584619
# 3                                 -1308.619072
# 4                                 -4775.862070
#
#    people_fully_vaccinated_seasonal_shift_b_1m  \
# 0                                 -4775.862070
# 1                                  2608.896523
# 2                                  3475.584619
# 3                                 -1308.619072
# 4                                 -4775.862070
#
#    people_fully_vaccinated_seasonal_shift_1m  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                -4775.86207
#
#    people_fully_vaccinated_seasonal_shift_2m  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    people_fully_vaccinated_seasonal_shift_3m  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    hosp_patients_seasonal_shift_b_2m  hosp_patients_seasonal_shift_b_1m  \
# 0                         -29.187786                         -29.187786
# 1                         -44.212947                         -44.212947
# 2                          -1.324852                          -1.324852
# 3                          74.725585                          74.725585
# 4                         -29.187786                         -29.187786
#
#    hosp_patients_seasonal_shift_1m  hosp_patients_seasonal_shift_2m  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                       -29.187786                              NaN
#
#    hosp_patients_seasonal_shift_3m  total_deaths_seasonal_shift_b_2m  \
# 0                              NaN                         37.982584
# 1                              NaN                         20.448755
# 2                              NaN                        -25.079221
# 3                              NaN                        -33.352118
# 4                              NaN                         37.982584
#
#    total_deaths_seasonal_shift_b_1m  total_deaths_seasonal_shift_1m  \
# 0                         37.982584                             NaN
# 1                         20.448755                             NaN
# 2                        -25.079221                             NaN
# 3                        -33.352118                             NaN
# 4                         37.982584                       37.982584
#
#    total_deaths_seasonal_shift_2m  total_deaths_seasonal_shift_3m  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    total_tests_seasonal_shift_b_2m  total_tests_seasonal_shift_b_1m  \
# 0                    -19421.186488                    -19421.186488
# 1                      9300.968274                      9300.968274
# 2                     14548.774226                     14548.774226
# 3                     -4428.556012                     -4428.556012
# 4                    -19421.186488                    -19421.186488
#
#    total_tests_seasonal_shift_1m  total_tests_seasonal_shift_2m  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                  -19421.186488                            NaN
#
#    total_tests_seasonal_shift_3m  stringency_index_seasonal_shift_b_2m  \
# 0                            NaN                             -0.907891
# 1                            NaN                             -0.620532
# 2                            NaN                              0.479515
# 3                            NaN                              1.048908
# 4                            NaN                             -0.907891
#
#    stringency_index_seasonal_shift_b_1m  stringency_index_seasonal_shift_1m  \
# 0                             -0.907891                                 NaN
# 1                             -0.620532                                 NaN
# 2                              0.479515                                 NaN
# 3                              1.048908                                 NaN
# 4                             -0.907891                           -0.907891
#
#    stringency_index_seasonal_shift_2m  stringency_index_seasonal_shift_3m
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
N_SPLITS = 3

X = df['date']
Y = df['stringency_index']

folds = TimeSeriesSplit(n_splits=N_SPLITS)

# %%
fig, ax = plt.subplots(nrows=N_SPLITS, ncols=2, figsize=(16, 9))

for i, (train_index, test_index) in enumerate(folds.split(X)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    sns.lineplot(
        x=X_train,
        y=y_train,
        ax=ax[i, 0],
        color='indianred',
        label='train'
    )
    sns.lineplot(
        x=X_train[len(X_train) - len(X_test):(len(X_train) - len(X_test) + len(X_test))],
        y=y_train[len(X_train) - len(X_test):(len(X_train) - len(X_test) + len(X_test))],
        ax=ax[i, 1],
        color='indianred',
        label='train'
    )
    
    for j in range(2):
        sns.lineplot(
            x=X_test,
            y=y_test,
            ax=ax[i, j],
            color='dodgerblue',
            label='test'
        )
    ax[i, 0].set_title(f"Rolling Window with Adjusting Training Size (Split {i+1})", fontsize=16)
    ax[i, 1].set_title(f"Rolling Window with Constant Training Size (Split {i+1})", fontsize=16)
    
for i in range(N_SPLITS):
    ax[i, 0].set_xlim([date(2020, 1, 1), date(2021, 4, 26)])
    ax[i, 1].set_xlim([date(2020, 1, 1), date(2021, 4, 26)])
    ax[i, 0].ticklabel_format(style='plain', axis='y')
    ax[i, 1].ticklabel_format(style='plain', axis='y')
    
fig.tight_layout()

# %%
train_size = int(0.85 * len(df))
test_size = len(df) - train_size

df_upr = df[['date', 'stringency_index']].copy()
df_upr.columns = ['ds', 'y']

train = u_df.iloc[:train_size, :]

x_train, y_train = pd.DataFrame(df_upr.iloc[:train_size, 0]), pd.DataFrame(df_upr.iloc[:train_size, 1])
x_test, y_test = pd.DataFrame(df_upr.iloc[train_size:, 0]), pd.DataFrame(df_upr.iloc[train_size:, 1])

print(len(train), len(x_test))
# Out:
# 51 10

# %%
model = pm.auto_arima(y_train, start_p=1, start_q=1,
                      test='adf',
                      max_p=7, max_q=7,
                      max_d=5, max_P=4,
                      max_D=4, max_Q=4,
                      m=4,
                      d=None,
                      seasonal=False,
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=329.155, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=341.750, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=327.323, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=332.814, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=341.536, Time=0.01 sec
# /home/mykull/miniconda3/envs/corona/lib/python3.8/site-packages/pmdarima/arima/_validation.py:62: UserWarning: m (4) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=329.085, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=330.492, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=326.254, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=327.974, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=328.052, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=332.220, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=329.384, Time=0.05 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 0.423 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -161.127
# Date:                Wed, 05 May 2021   AIC                            326.254
# Time:                        11:32:57   BIC                            330.078
# Sample:                             0   HQIC                           327.710
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6163      0.081      7.597      0.000       0.457       0.775
# sigma2        36.5122      5.274      6.923      0.000      26.175      46.849
# ===================================================================================
# Ljung-Box (Q):                       48.13   Jarque-Bera (JB):                21.84
# Prob(Q):                              0.18   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.49   Skew:                             0.95
# Prob(H) (two-sided):                  0.16   Kurtosis:                         5.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(16, 8));

# %%
model = Prophet()
model.fit(train)

y_pred=model.predict(x_test)

score_mae = mean_absolute_error(y_test, y_pred.tail(test_size)['yhat'])
score_rmse = math.sqrt(mean_squared_error(y_test, y_pred.tail(test_size)['yhat']))

print('RMSE: {}'.format(score_rmse))
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# RMSE: 4.538425062486359

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))

model.plot(y_pred, ax=ax)
sns.lineplot(x=x_test['ds'], y=y_test['y'], ax=ax, color='orange', label='Ground truth')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Stringency Index', fontsize=14)
# Out:
# Text(111.25, 0.5, 'Stringency Index')

# %%
model = ARIMA(y_train, order=(1,1,0))
model_fit = model.fit()

y_pred, se, conf = model_fit.forecast(10)

score_mae = mean_absolute_error(y_test, y_pred)
score_rmse = math.sqrt(mean_squared_error(y_test, y_pred))

print('RMSE: {}'.format(score_rmse))
# Out:
# RMSE: 13.165580059727201

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))

model_fit.plot_predict(2, 80, ax=ax)
sns.lineplot(x=x_test.index, y=y_test['y'], ax=ax, color='indianred', label='Ground truth')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Stringency Index', fontsize=14)
ax.ticklabel_format(style='plain', axis='y')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))

sns.lineplot(x=x_test.index, y=y_pred, ax=ax, color='blue', label='predicted')
sns.lineplot(x=x_test.index, y=y_test['y'], ax=ax, color='indianred', label='ground truth')

ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Stringency Index', fontsize=14)
ax.ticklabel_format(style='plain', axis='y')

# %%
feature_columns = [
    'total_cases',
    'people_vaccinated',
    'people_fully_vaccinated',
    'hosp_patients',
    'total_deaths',
    'total_tests',
    #'stringency_index'
]
target_column = ['stringency_index']

train_size = int(0.85 * len(df))

df_mpr = df[['date'] + target_column + feature_columns].copy()
df_mpr.columns = ['ds', 'y'] + feature_columns

train = df_mpr.iloc[:train_size, :]
x_train, y_train = pd.DataFrame(df_mpr.iloc[:train_size, [0,2,3,4,5,6,7]]), pd.DataFrame(df_mpr.iloc[:train_size, 1])
x_test, y_test = pd.DataFrame(df_mpr.iloc[train_size:, [0,2,3,4,5,6,7]]), pd.DataFrame(df_mpr.iloc[train_size:, 1])

# %%
model = Prophet()

model.add_regressor('total_cases')
model.add_regressor('people_vaccinated')
model.add_regressor('people_fully_vaccinated')
model.add_regressor('hosp_patients')
model.add_regressor('total_deaths')
model.add_regressor('total_tests')
#model.add_regressor('stringency_index')

model.fit(train)

y_pred = model.predict(x_test)

score_mae = mean_absolute_error(y_test, y_pred['yhat'])
score_rmse = math.sqrt(mean_squared_error(y_test, y_pred['yhat']))

print('RMSE: {}'.format(score_rmse))
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# RMSE: 4.158863529139413

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))

model.plot(y_pred, ax=ax)

sns.lineplot(x=x_test['ds'], y=y_test['y'], ax=ax, color='orange', label='Ground truth')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Stringency Index', fontsize=14)
# Out:
# Text(111.25, 0.5, 'Stringency Index')
